# %% [markdown]
# <a href="https://colab.research.google.com/github/Prizrak2/Modelo-IA-Roupas/blob/main/Modelo_IA_Roupas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#imports
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

#carregando dados
dataset = keras.datasets.fashion_mnist
((imagens_treino, identificacoes_treino),(imagens_teste, identificacoes_teste)) = dataset.load_data()

#classificando dados
total_de_classificacoes = 10
nomes_de_classificacoes = ['Camiseta', 'Calca', 'Suéter', 'Vestido', 'Casaco', 'Sandalia', 'Camisa', 'Tênis', 'Bolsa', 'Bota']

# %%
imagens_treino = imagens_treino/float(255)
modelo = keras.Sequential([
    #entrada
    keras.layers.Flatten(input_shape = (28,28)),
    #oculta-
    keras.layers.Dense(256, activation=tf.nn.relu),
    keras.layers.Dropout(0.2),
    #saida
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

modelo.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

historico = modelo.fit(imagens_treino, identificacoes_treino, epochs=50, validation_split=0.2)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.7659 - loss: 0.6710 - val_accuracy: 0.8551 - val_loss: 0.4038
# Epoch 2/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.8524 - loss: 0.4001 - val_accuracy: 0.8596 - val_loss: 0.3898
# Epoch 3/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8642 - loss: 0.3674 - val_accuracy: 0.8698 - val_loss: 0.3513
# Epoch 4/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.8755 - loss: 0.3365 - val_accuracy: 0.8818 - val_loss: 0.3318
# Epoch 5/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.8815 - loss: 0.3152 - val_accuracy: 0.8785 - val_loss: 0.3342
# Epoch 6/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.8844 - loss: 0.3069 - val_accuracy: 0.8823 - val_loss: 0.3254
# Epoch 7/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8884 - loss: 0.2984 - val_accuracy: 0.8831 - val_loss: 0.3260
# Epoch 8/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8958 - loss: 0.2867 - val_accuracy: 0.8798 - val_loss: 0.3382
# Epoch 9/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.8946 - loss: 0.2785 - val_accuracy: 0.8848 - val_loss: 0.3227
# Epoch 10/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 6ms/step - accuracy: 0.9010 - loss: 0.2711 - val_accuracy: 0.8881 - val_loss: 0.3132
# Epoch 11/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9032 - loss: 0.2605 - val_accuracy: 0.8879 - val_loss: 0.3212
# Epoch 12/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9066 - loss: 0.2531 - val_accuracy: 0.8854 - val_loss: 0.3222
# Epoch 13/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9105 - loss: 0.2416 - val_accuracy: 0.8908 - val_loss: 0.3046
# Epoch 14/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9065 - loss: 0.2508 - val_accuracy: 0.8947 - val_loss: 0.3136
# Epoch 15/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9116 - loss: 0.2292 - val_accuracy: 0.8916 - val_loss: 0.3157
# Epoch 16/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9139 - loss: 0.2298 - val_accuracy: 0.8881 - val_loss: 0.3296
# Epoch 17/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9143 - loss: 0.2264 - val_accuracy: 0.8894 - val_loss: 0.3275
# Epoch 18/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9172 - loss: 0.2179 - val_accuracy: 0.8913 - val_loss: 0.3231
# Epoch 19/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9174 - loss: 0.2157 - val_accuracy: 0.8923 - val_loss: 0.3227
# Epoch 20/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9173 - loss: 0.2149 - val_accuracy: 0.8965 - val_loss: 0.3048
# Epoch 21/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9246 - loss: 0.2002 - val_accuracy: 0.8947 - val_loss: 0.3206
# Epoch 22/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9247 - loss: 0.1986 - val_accuracy: 0.8939 - val_loss: 0.3298
# Epoch 23/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9227 - loss: 0.1976 - val_accuracy: 0.8915 - val_loss: 0.3257
# Epoch 24/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9265 - loss: 0.1934 - val_accuracy: 0.8947 - val_loss: 0.3301
# Epoch 25/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9280 - loss: 0.1886 - val_accuracy: 0.8923 - val_loss: 0.3320
# Epoch 26/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9284 - loss: 0.1902 - val_accuracy: 0.8916 - val_loss: 0.3405
# Epoch 27/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9279 - loss: 0.1898 - val_accuracy: 0.8945 - val_loss: 0.3215
# Epoch 28/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9318 - loss: 0.1779 - val_accuracy: 0.8979 - val_loss: 0.3319
# Epoch 29/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9326 - loss: 0.1775 - val_accuracy: 0.8974 - val_loss: 0.3440
# Epoch 30/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9325 - loss: 0.1764 - val_accuracy: 0.8880 - val_loss: 0.3614
# Epoch 31/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9341 - loss: 0.1717 - val_accuracy: 0.8990 - val_loss: 0.3386
# Epoch 32/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9337 - loss: 0.1742 - val_accuracy: 0.8965 - val_loss: 0.3379
# Epoch 33/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9367 - loss: 0.1651 - val_accuracy: 0.8935 - val_loss: 0.3561
# Epoch 34/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.9357 - loss: 0.1670 - val_accuracy: 0.8937 - val_loss: 0.3623
# Epoch 35/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9344 - loss: 0.1720 - val_accuracy: 0.8974 - val_loss: 0.3450
# Epoch 36/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9337 - loss: 0.1688 - val_accuracy: 0.8940 - val_loss: 0.3497
# Epoch 37/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9365 - loss: 0.1658 - val_accuracy: 0.8950 - val_loss: 0.3532
# Epoch 38/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9409 - loss: 0.1552 - val_accuracy: 0.8968 - val_loss: 0.3560
# Epoch 39/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9410 - loss: 0.1565 - val_accuracy: 0.8953 - val_loss: 0.3629
# Epoch 40/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9418 - loss: 0.1543 - val_accuracy: 0.8962 - val_loss: 0.3686
# Epoch 41/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9414 - loss: 0.1547 - val_accuracy: 0.8927 - val_loss: 0.3840
# Epoch 42/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9384 - loss: 0.1578 - val_accuracy: 0.8953 - val_loss: 0.3809
# Epoch 43/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9423 - loss: 0.1508 - val_accuracy: 0.8953 - val_loss: 0.3743
# Epoch 44/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9439 - loss: 0.1447 - val_accuracy: 0.8968 - val_loss: 0.3830
# Epoch 45/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9445 - loss: 0.1472 - val_accuracy: 0.8940 - val_loss: 0.4087
# Epoch 46/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9460 - loss: 0.1432 - val_accuracy: 0.8961 - val_loss: 0.3859
# Epoch 47/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9434 - loss: 0.1464 - val_accuracy: 0.8955 - val_loss: 0.3789
# Epoch 48/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9436 - loss: 0.1456 - val_accuracy: 0.8962 - val_loss: 0.3921
# Epoch 49/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9431 - loss: 0.1443 - val_accuracy: 0.8978 - val_loss: 0.3882
# Epoch 50/50
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9473 - loss: 0.1366 - val_accuracy: 0.8953 - val_loss: 0.4086

# %%
plt.plot(historico.history['accuracy'])
plt.plot(historico.history['val_accuracy'])
plt.title('Acuracia do modelo')
plt.xlabel('Epocas')
plt.ylabel('Acuracia')
plt.legend(['treino', 'validacao'])

# %%
plt.plot(historico.history['loss'])
plt.plot(historico.history['val_loss'])
plt.title('Perda do modelo')
plt.xlabel('Epocas')
plt.ylabel('Perda')
plt.legend(['treino', 'validacao'])

# %%
perda_teste, acuracia_teste = modelo.evaluate(imagens_teste, identificacoes_teste)
print('Perda do teste: ', perda_teste)
print('Acuracia do teste: ', acuracia_teste)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8754 - loss: 96.5263
# Perda do teste:  98.54243469238281
# Acuracia do teste:  0.8762999773025513
